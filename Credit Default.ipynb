# %% [markdown]
# # Cregit Default

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(color_codes=True)
# %matplotlib inline

# %% [markdown]
# ## Data Exploration

# %%
filepath = 'C:/Users/Constantinos/Credit -Default/default of credit card clients.csv'
credit = pd.read_csv(filepath, header =1)
credit.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...          0          0          0         0       689         0
# 1  ...       3272       3455       3261         0      1000      1000
# 2  ...      14331      14948      15549      1518      1500      1000
# 3  ...      28314      28959      29547      2000      2019      1200
# 4  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %%
display(credit)
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          1      20000    2          2         1   24      2      2     -1
# 1          2     120000    2          2         2   26     -1      2      0
# 2          3      90000    2          2         2   34      0      0      0
# 3          4      50000    2          2         1   37      0      0      0
# 4          5      50000    1          2         1   57     -1      0     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43     -1     -1     -1
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1     -1      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
# ...

# %%
credit.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# ...

# %%
credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
# ID                            30000 non-null int64
# LIMIT_BAL                     30000 non-null int64
# SEX                           30000 non-null int64
# EDUCATION                     30000 non-null int64
# MARRIAGE                      30000 non-null int64
# AGE                           30000 non-null int64
# PAY_0                         30000 non-null int64
# PAY_2                         30000 non-null int64
# PAY_3                         30000 non-null int64
# PAY_4                         30000 non-null int64
# PAY_5                         30000 non-null int64
# PAY_6                         30000 non-null int64
# BILL_AMT1                     30000 non-null int64
# BILL_AMT2                     30000 non-null int64
# BILL_AMT3                     30000 non-null int64
# BILL_AMT4                     30000 non-null int64
# ...

# %%
print(credit.groupby('SEX').size())
print(credit.groupby('EDUCATION').size())
print(credit.groupby('MARRIAGE').size())
# Out:
# SEX
# 1    11888
# 2    18112
# dtype: int64
# EDUCATION
# 0       14
# 1    10585
# 2    14030
# 3     4917
# 4      123
# 5      280
# 6       51
# dtype: int64
# MARRIAGE
# 0       54
# 1    13659
# 2    15964
# 3      323
# dtype: int64

# %% [markdown]
# ## Visualization

# %%
plt.hist(credit['LIMIT_BAL'],bins=20)
plt.show()

# %%
# Calculate number of unique values for each label: num_unique_labels
num_unique_labels = df[LABELS].apply(pd.Series.nunique)

# Plot number of unique values for each label
num_unique_labels.plot(kind='bar')

# Label the axes
plt.xlabel('Labels')
plt.ylabel('Number of unique values')

# Display the plot
plt.show()

# %%
sns.pairplot(credit, hue='EDUCATION', height=3, aspect=1);

# %%
credit.hist(edgecolor='black', linewidth=1.2, figsize=(12,8));
plt.show();

# %%
plt.figure(figsize=(12,8));
plt.subplot(2,2,1)
sns.violinplot(x='species', y='sepal_length', data=credit)
plt.subplot(2,2,2)
sns.violinplot(x='species', y='sepal_width', data=credit)
plt.subplot(2,2,3)
sns.violinplot(x='species', y='petal_length', data=credit)
plt.subplot(2,2,4)
sns.violinplot(x='species', y='petal_width', data=credit);

# %%
credit.boxplot(by='MARIAGE', figsize=(12,8));

# %%
pd.plotting.scatter_matrix(credit, figsize=(12,10))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-8828c348501d> in <module>
#       1 pd.plotting.scatter_matrix(credit, figsize=(12,10))
# ----> 2 plt.show()
#
# ~\Anaconda3\envs\MachineLearning Andrew Ng\lib\site-packages\matplotlib\pyplot.py in show(*args, **kw)
#     261     """
#     262     global _show
# --> 263     return _show(*args, **kw)
#     264
#     265
#
# ~\Anaconda3\envs\MachineLearning Andrew Ng\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      37             display(
#      38                 figure_manager.canvas.figure,
# ---> 39                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      40             )
#      41     finally:
#
# ...

# %%
sns.pairplot(credit, hue="EDUCATION",diag_kind="kde");
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-b2f2f9c4ee13> in <module>
# ----> 1 sns.pairplot(credit, hue="EDUCATION",diag_kind="kde");
#
# ~\Anaconda3\envs\MachineLearning Andrew Ng\lib\site-packages\seaborn\axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, dropna, plot_kws, diag_kws, grid_kws, size)
#    2082                     hue_order=hue_order, palette=palette,
#    2083                     diag_sharey=diag_sharey,
# -> 2084                     height=height, aspect=aspect, dropna=dropna, **grid_kws)
#    2085
#    2086     # Add the markers here as PairGrid has figured out how many levels of the
#
# ...

# %%
plt.plot(credit['LIMIT_BAL'])
plt.show()

# %%
x = credit['PAY_0']
y = credit['PAY_2']
plt.figure(figsize=(16,6))
plt.scatter(x,y)
plt.show()

# %%
A = credit['BILL_AMT1']
plt.boxplot(A,0,'gD')
plt.show()

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt
credit.hist(bins=50, figsize=(20,15))
plt.show()

# %% [markdown]
# ## Corelation

# %%
corrMat = credit.corr()
print(corrMat)
# Out:
#                                   ID  LIMIT_BAL       SEX  EDUCATION  \
# ID                          1.000000   0.026179  0.018497   0.039177
# LIMIT_BAL                   0.026179   1.000000  0.024755  -0.219161
# SEX                         0.018497   0.024755  1.000000   0.014232
# EDUCATION                   0.039177  -0.219161  0.014232   1.000000
# MARRIAGE                   -0.029079  -0.108139 -0.031389  -0.143464
# AGE                         0.018678   0.144713 -0.090874   0.175061
# PAY_0                      -0.030575  -0.271214 -0.057643   0.105364
# PAY_2                      -0.011215  -0.296382 -0.070771   0.121566
# PAY_3                      -0.018494  -0.286123 -0.066096   0.114025
# PAY_4                      -0.002735  -0.267460 -0.060173   0.108793
# PAY_5                      -0.022199  -0.249411 -0.055064   0.097520
# PAY_6                      -0.020270  -0.235195 -0.044008   0.082316
# BILL_AMT1                   0.019389   0.285430 -0.033642   0.023581
# ...

# %% [markdown]
# ## Covariance

# %%
covMat = credit.cov()
print(covMat)
# Out:
#                                       ID     LIMIT_BAL          SEX  \
# ID                          7.500250e+07  2.941664e+07    78.356379
# LIMIT_BAL                   2.941664e+07  1.683446e+10  1571.050630
# SEX                         7.835638e+01  1.571051e+03     0.239247
# EDUCATION                   2.681543e+02 -2.247403e+04     0.005502
# MARRIAGE                   -1.314525e+02 -7.323670e+03    -0.008014
# AGE                         1.491057e+03  1.730767e+05    -0.409726
# PAY_0                      -2.975726e+02 -3.954593e+04    -0.031685
# PAY_2                      -1.162770e+02 -4.603765e+04    -0.041442
# PAY_3                      -1.916922e+02 -4.443225e+04    -0.038694
# PAY_4                      -2.769132e+01 -4.057181e+04    -0.034411
# PAY_5                      -2.178600e+02 -3.667056e+04    -0.030521
# PAY_6                      -2.018774e+02 -3.509308e+04    -0.024754
# BILL_AMT1                   1.236447e+07  2.727020e+09 -1211.694332
# ...

# %%
# check for missing values
pd.isnull(credit)
# Out:
#           ID  LIMIT_BAL    SEX  EDUCATION  MARRIAGE    AGE  PAY_0  PAY_2  \
# 0      False      False  False      False     False  False  False  False
# 1      False      False  False      False     False  False  False  False
# 2      False      False  False      False     False  False  False  False
# 3      False      False  False      False     False  False  False  False
# 4      False      False  False      False     False  False  False  False
# 5      False      False  False      False     False  False  False  False
# 6      False      False  False      False     False  False  False  False
# 7      False      False  False      False     False  False  False  False
# 8      False      False  False      False     False  False  False  False
# 9      False      False  False      False     False  False  False  False
# 10     False      False  False      False     False  False  False  False
# 11     False      False  False      False     False  False  False  False
# ...

# %%
credit.SEX
# Out:
# 0        2
# 1        2
# 2        2
# 3        2
# 4        1
# 5        1
# 6        1
# 7        2
# 8        2
# 9        1
# 10       2
# 11       2
# 12       2
# 13       1
# 14       1
# 15       2
# 16       1
# 17       1
# 18       2
# 19       2
# 20       2
# 21       2
# 22       2
# 23       2
# 24       1
# 25       1
# 26       1
# 27       2
# 28       2
# 29       1
#         ..
# 29970    1
# 29971    1
# 29972    1
# 29973    1
# 29974    1
# 29975    1
# 29976    1
# 29977    1
# 29978    1
# 29979    1
# 29980    1
# 29981    1
# 29982    1
# 29983    1
# 29984    1
# 29985    1
# 29986    1
# 29987    1
# 29988    1
# 29989    1
# 29990    1
# 29991    1
# 29992    1
# 29993    1
# 29994    1
# 29995    1
# 29996    1
# 29997    1
# 29998    1
# 29999    1
# Name: SEX, Length: 30000, dtype: int64

# %%
#check row 29988 
credit.loc[29988]
# Out:
# ID                             29989
# LIMIT_BAL                     250000
# SEX                                1
# EDUCATION                          1
# MARRIAGE                           1
# AGE                               34
# PAY_0                              0
# PAY_2                              0
# PAY_3                              0
# PAY_4                              0
# PAY_5                              0
# PAY_6                              0
# BILL_AMT1                     279640
# BILL_AMT2                     252913
# BILL_AMT3                     243075
# BILL_AMT4                     245750
# BILL_AMT5                     175005
# BILL_AMT6                     179687
# PAY_AMT1                       65000
# PAY_AMT2                        8800
# PAY_AMT3                        9011
# PAY_AMT4                        6000
# PAY_AMT5                        7000
# PAY_AMT6                        6009
# default payment next month         0
# ...

# %%
# Check for unique values
pd.unique(credit['SEX'])
# Out:
# array([2, 1], dtype=int64)

# %%
# Check for unique values
pd.value_counts(credit['SEX'])
# Out:
# 2    18112
# 1    11888
# Name: SEX, dtype: int64

# %%
# check for missing values
credit.isnull().sum()
# Out:
# ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default payment next month    0
# dtype: int64

# %%
# dpop NAs
